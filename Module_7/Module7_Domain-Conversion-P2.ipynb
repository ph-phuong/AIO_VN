# %% [markdown]
# ## Download Data

# %%
# Khoa_LHR_image.zip
# !gdown --id 1bsWkNmmYvBrgE1c58SGJFcCjQv3SUyH3
# Out:
# /usr/local/lib/python3.10/dist-packages/gdown/__main__.py:140: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From (original): https://drive.google.com/uc?id=1bsWkNmmYvBrgE1c58SGJFcCjQv3SUyH3
# From (redirected): https://drive.google.com/uc?id=1bsWkNmmYvBrgE1c58SGJFcCjQv3SUyH3&confirm=t&uuid=567084a0-d535-4710-96fc-475d6773ba14
# To: /content/Khoa_LHR_image.zip
# 100% 89.0M/89.0M [00:01<00:00, 70.0MB/s]

# %%
# !pip install torcheval
# Out:
# Collecting torcheval
#   Downloading torcheval-0.0.7-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torcheval) (4.12.2)
# Downloading torcheval-0.0.7-py3-none-any.whl (179 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.2/179.2 kB 10.7 MB/s eta 0:00:00
# Installing collected packages: torcheval
# Successfully installed torcheval-0.0.7

# %%
# !unzip /content/Khoa_LHR_image.zip
# Out:
# Archive:  /content/Khoa_LHR_image.zip
#    creating: Khoa_LHR_image/
#    creating: Khoa_LHR_image/train/
#   inflating: Khoa_LHR_image/train/0.png
#   inflating: Khoa_LHR_image/train/1.png
#   inflating: Khoa_LHR_image/train/10.png
#   inflating: Khoa_LHR_image/train/100.png
#   inflating: Khoa_LHR_image/train/101.png
#   inflating: Khoa_LHR_image/train/102.png
#   inflating: Khoa_LHR_image/train/103.png
#   inflating: Khoa_LHR_image/train/104.png
#   inflating: Khoa_LHR_image/train/105.png
#   inflating: Khoa_LHR_image/train/106.png
#   inflating: Khoa_LHR_image/train/107.png
#   inflating: Khoa_LHR_image/train/108.png
#   inflating: Khoa_LHR_image/train/109.png
#   inflating: Khoa_LHR_image/train/11.png
#   inflating: Khoa_LHR_image/train/110.png
#   inflating: Khoa_LHR_image/train/111.png
#   inflating: Khoa_LHR_image/train/112.png
#   inflating: Khoa_LHR_image/train/113.png
#   inflating: Khoa_LHR_image/train/114.png
#   inflating: Khoa_LHR_image/train/115.png
#   inflating: Khoa_LHR_image/train/116.png
#   inflating: Khoa_LHR_image/train/117.png
#   inflating: Khoa_LHR_image/train/118.png
#   inflating: Khoa_LHR_image/train/119.png
#   inflating: Khoa_LHR_image/train/12.png
#   inflating: Khoa_LHR_image/train/120.png
#   inflating: Khoa_LHR_image/train/121.png
#   inflating: Khoa_LHR_image/train/122.png
#   inflating: Khoa_LHR_image/train/123.png
#   inflating: Khoa_LHR_image/train/124.png
#   inflating: Khoa_LHR_image/train/125.png
#   inflating: Khoa_LHR_image/train/126.png
#   inflating: Khoa_LHR_image/train/127.png
#   inflating: Khoa_LHR_image/train/128.png
#   inflating: Khoa_LHR_image/train/129.png
#   inflating: Khoa_LHR_image/train/13.png
#   inflating: Khoa_LHR_image/train/130.png
#   inflating: Khoa_LHR_image/train/131.png
#   inflating: Khoa_LHR_image/train/132.png
#   inflating: Khoa_LHR_image/train/133.png
#   inflating: Khoa_LHR_image/train/134.png
#   inflating: Khoa_LHR_image/train/135.png
#   inflating: Khoa_LHR_image/train/136.png
#   inflating: Khoa_LHR_image/train/137.png
#   inflating: Khoa_LHR_image/train/138.png
#   inflating: Khoa_LHR_image/train/139.png
#   inflating: Khoa_LHR_image/train/14.png
#   inflating: Khoa_LHR_image/train/140.png
#   inflating: Khoa_LHR_image/train/141.png
#   inflating: Khoa_LHR_image/train/142.png
#   inflating: Khoa_LHR_image/train/143.png
#   inflating: Khoa_LHR_image/train/144.png
#   inflating: Khoa_LHR_image/train/145.png
#   inflating: Khoa_LHR_image/train/146.png
#   inflating: Khoa_LHR_image/train/147.png
#   inflating: Khoa_LHR_image/train/148.png
#   inflating: Khoa_LHR_image/train/149.png
#   inflating: Khoa_LHR_image/train/15.png
#   inflating: Khoa_LHR_image/train/150.png
#   inflating: Khoa_LHR_image/train/151.png
#   inflating: Khoa_LHR_image/train/152.png
#   inflating: Khoa_LHR_image/train/153.png
#   inflating: Khoa_LHR_image/train/154.png
#   inflating: Khoa_LHR_image/train/155.png
#   inflating: Khoa_LHR_image/train/156.png
#   inflating: Khoa_LHR_image/train/157.png
#   inflating: Khoa_LHR_image/train/158.png
#   inflating: Khoa_LHR_image/train/159.png
#   inflating: Khoa_LHR_image/train/16.png
#   inflating: Khoa_LHR_image/train/160.png
#   inflating: Khoa_LHR_image/train/161.png
#   inflating: Khoa_LHR_image/train/162.png
#   inflating: Khoa_LHR_image/train/163.png
#   inflating: Khoa_LHR_image/train/164.png
#   inflating: Khoa_LHR_image/train/165.png
#   inflating: Khoa_LHR_image/train/166.png
#   inflating: Khoa_LHR_image/train/167.png
#   inflating: Khoa_LHR_image/train/168.png
#   inflating: Khoa_LHR_image/train/169.png
#   inflating: Khoa_LHR_image/train/17.png
#   inflating: Khoa_LHR_image/train/170.png
#   inflating: Khoa_LHR_image/train/171.png
#   inflating: Khoa_LHR_image/train/172.png
#   inflating: Khoa_LHR_image/train/173.png
#   inflating: Khoa_LHR_image/train/174.png
#   inflating: Khoa_LHR_image/train/175.png
#   inflating: Khoa_LHR_image/train/176.png
#   inflating: Khoa_LHR_image/train/177.png
#   inflating: Khoa_LHR_image/train/178.png
#   inflating: Khoa_LHR_image/train/179.png
#   inflating: Khoa_LHR_image/train/18.png
#   inflating: Khoa_LHR_image/train/180.png
#   inflating: Khoa_LHR_image/train/181.png
#   inflating: Khoa_LHR_image/train/182.png
#   inflating: Khoa_LHR_image/train/183.png
#   inflating: Khoa_LHR_image/train/184.png
#   inflating: Khoa_LHR_image/train/185.png
#   inflating: Khoa_LHR_image/train/186.png
#   inflating: Khoa_LHR_image/train/187.png
#   inflating: Khoa_LHR_image/train/188.png
#   inflating: Khoa_LHR_image/train/189.png
#   inflating: Khoa_LHR_image/train/19.png
#   inflating: Khoa_LHR_image/train/190.png
#   inflating: Khoa_LHR_image/train/191.png
#   inflating: Khoa_LHR_image/train/192.png
#   inflating: Khoa_LHR_image/train/193.png
#   inflating: Khoa_LHR_image/train/194.png
#   inflating: Khoa_LHR_image/train/195.png
#   inflating: Khoa_LHR_image/train/196.png
#   inflating: Khoa_LHR_image/train/197.png
#   inflating: Khoa_LHR_image/train/198.png
#   inflating: Khoa_LHR_image/train/199.png
#   inflating: Khoa_LHR_image/train/2.png
#   inflating: Khoa_LHR_image/train/20.png
#   inflating: Khoa_LHR_image/train/200.png
#   inflating: Khoa_LHR_image/train/201.png
#   inflating: Khoa_LHR_image/train/202.png
#   inflating: Khoa_LHR_image/train/203.png
#   inflating: Khoa_LHR_image/train/204.png
#   inflating: Khoa_LHR_image/train/205.png
#   inflating: Khoa_LHR_image/train/206.png
#   inflating: Khoa_LHR_image/train/207.png
#   inflating: Khoa_LHR_image/train/208.png
#   inflating: Khoa_LHR_image/train/209.png
#   inflating: Khoa_LHR_image/train/21.png
#   inflating: Khoa_LHR_image/train/210.png
#   inflating: Khoa_LHR_image/train/211.png
#   inflating: Khoa_LHR_image/train/212.png
#   inflating: Khoa_LHR_image/train/213.png
#   inflating: Khoa_LHR_image/train/214.png
#   inflating: Khoa_LHR_image/train/215.png
#   inflating: Khoa_LHR_image/train/216.png
#   inflating: Khoa_LHR_image/train/217.png
#   inflating: Khoa_LHR_image/train/218.png
#   inflating: Khoa_LHR_image/train/219.png
#   inflating: Khoa_LHR_image/train/22.png
#   inflating: Khoa_LHR_image/train/220.png
#   inflating: Khoa_LHR_image/train/221.png
#   inflating: Khoa_LHR_image/train/222.png
#   inflating: Khoa_LHR_image/train/223.png
#   inflating: Khoa_LHR_image/train/224.png
#   inflating: Khoa_LHR_image/train/225.png
#   inflating: Khoa_LHR_image/train/226.png
#   inflating: Khoa_LHR_image/train/227.png
#   inflating: Khoa_LHR_image/train/228.png
#   inflating: Khoa_LHR_image/train/229.png
#   inflating: Khoa_LHR_image/train/23.png
#   inflating: Khoa_LHR_image/train/230.png
#   inflating: Khoa_LHR_image/train/231.png
#   inflating: Khoa_LHR_image/train/232.png
#   inflating: Khoa_LHR_image/train/233.png
#   inflating: Khoa_LHR_image/train/234.png
#   inflating: Khoa_LHR_image/train/235.png
#   inflating: Khoa_LHR_image/train/236.png
#   inflating: Khoa_LHR_image/train/237.png
#   inflating: Khoa_LHR_image/train/238.png
#   inflating: Khoa_LHR_image/train/239.png
#   inflating: Khoa_LHR_image/train/24.png
#   inflating: Khoa_LHR_image/train/240.png
#   inflating: Khoa_LHR_image/train/241.png
#   inflating: Khoa_LHR_image/train/242.png
#   inflating: Khoa_LHR_image/train/243.png
#   inflating: Khoa_LHR_image/train/244.png
#   inflating: Khoa_LHR_image/train/245.png
#   inflating: Khoa_LHR_image/train/246.png
#   inflating: Khoa_LHR_image/train/247.png
#   inflating: Khoa_LHR_image/train/248.png
#   inflating: Khoa_LHR_image/train/249.png
#   inflating: Khoa_LHR_image/train/25.png
#   inflating: Khoa_LHR_image/train/250.png
#   inflating: Khoa_LHR_image/train/251.png
#   inflating: Khoa_LHR_image/train/252.png
#   inflating: Khoa_LHR_image/train/253.png
#   inflating: Khoa_LHR_image/train/254.png
#   inflating: Khoa_LHR_image/train/255.png
#   inflating: Khoa_LHR_image/train/256.png
#   inflating: Khoa_LHR_image/train/257.png
#   inflating: Khoa_LHR_image/train/258.png
#   inflating: Khoa_LHR_image/train/259.png
#   inflating: Khoa_LHR_image/train/26.png
#   inflating: Khoa_LHR_image/train/260.png
#   inflating: Khoa_LHR_image/train/261.png
#   inflating: Khoa_LHR_image/train/262.png
#   inflating: Khoa_LHR_image/train/263.png
#   inflating: Khoa_LHR_image/train/264.png
#   inflating: Khoa_LHR_image/train/265.png
#   inflating: Khoa_LHR_image/train/266.png
#   inflating: Khoa_LHR_image/train/267.png
#   inflating: Khoa_LHR_image/train/268.png
#   inflating: Khoa_LHR_image/train/269.png
#   inflating: Khoa_LHR_image/train/27.png
#   inflating: Khoa_LHR_image/train/270.png
#   inflating: Khoa_LHR_image/train/271.png
#   inflating: Khoa_LHR_image/train/272.png
#   inflating: Khoa_LHR_image/train/273.png
#   inflating: Khoa_LHR_image/train/274.png
#   inflating: Khoa_LHR_image/train/275.png
#   inflating: Khoa_LHR_image/train/276.png
#   inflating: Khoa_LHR_image/train/277.png
#   inflating: Khoa_LHR_image/train/278.png
#   inflating: Khoa_LHR_image/train/279.png
#   inflating: Khoa_LHR_image/train/28.png
#   inflating: Khoa_LHR_image/train/280.png
#   inflating: Khoa_LHR_image/train/281.png
#   inflating: Khoa_LHR_image/train/282.png
#   inflating: Khoa_LHR_image/train/283.png
#   inflating: Khoa_LHR_image/train/284.png
#   inflating: Khoa_LHR_image/train/285.png
#   inflating: Khoa_LHR_image/train/286.png
#   inflating: Khoa_LHR_image/train/287.png
#   inflating: Khoa_LHR_image/train/288.png
#   inflating: Khoa_LHR_image/train/289.png
#   inflating: Khoa_LHR_image/train/29.png
#   inflating: Khoa_LHR_image/train/290.png
#   inflating: Khoa_LHR_image/train/291.png
#   inflating: Khoa_LHR_image/train/292.png
#   inflating: Khoa_LHR_image/train/293.png
#   inflating: Khoa_LHR_image/train/294.png
#   inflating: Khoa_LHR_image/train/295.png
#   inflating: Khoa_LHR_image/train/296.png
#   inflating: Khoa_LHR_image/train/297.png
#   inflating: Khoa_LHR_image/train/298.png
#   inflating: Khoa_LHR_image/train/299.png
#   inflating: Khoa_LHR_image/train/3.png
#   inflating: Khoa_LHR_image/train/30.png
#   inflating: Khoa_LHR_image/train/300.png
#   inflating: Khoa_LHR_image/train/301.png
#   inflating: Khoa_LHR_image/train/302.png
#   inflating: Khoa_LHR_image/train/303.png
#   inflating: Khoa_LHR_image/train/304.png
#   inflating: Khoa_LHR_image/train/305.png
#   inflating: Khoa_LHR_image/train/306.png
#   inflating: Khoa_LHR_image/train/307.png
#   inflating: Khoa_LHR_image/train/308.png
#   inflating: Khoa_LHR_image/train/309.png
#   inflating: Khoa_LHR_image/train/31.png
#   inflating: Khoa_LHR_image/train/310.png
#   inflating: Khoa_LHR_image/train/311.png
#   inflating: Khoa_LHR_image/train/312.png
#   inflating: Khoa_LHR_image/train/313.png
#   inflating: Khoa_LHR_image/train/314.png
#   inflating: Khoa_LHR_image/train/315.png
#   inflating: Khoa_LHR_image/train/316.png
#   inflating: Khoa_LHR_image/train/317.png
#   inflating: Khoa_LHR_image/train/318.png
#   inflating: Khoa_LHR_image/train/319.png
#   inflating: Khoa_LHR_image/train/32.png
#   inflating: Khoa_LHR_image/train/320.png
#   inflating: Khoa_LHR_image/train/321.png
#   inflating: Khoa_LHR_image/train/322.png
#   inflating: Khoa_LHR_image/train/323.png
#   inflating: Khoa_LHR_image/train/324.png
#   inflating: Khoa_LHR_image/train/325.png
#   inflating: Khoa_LHR_image/train/326.png
#   inflating: Khoa_LHR_image/train/327.png
#   inflating: Khoa_LHR_image/train/328.png
#   inflating: Khoa_LHR_image/train/329.png
#   inflating: Khoa_LHR_image/train/33.png
#   inflating: Khoa_LHR_image/train/330.png
#   inflating: Khoa_LHR_image/train/331.png
#   inflating: Khoa_LHR_image/train/332.png
#   inflating: Khoa_LHR_image/train/333.png
#   inflating: Khoa_LHR_image/train/334.png
#   inflating: Khoa_LHR_image/train/335.png
#   inflating: Khoa_LHR_image/train/336.png
#   inflating: Khoa_LHR_image/train/337.png
#   inflating: Khoa_LHR_image/train/338.png
#   inflating: Khoa_LHR_image/train/339.png
#   inflating: Khoa_LHR_image/train/34.png
#   inflating: Khoa_LHR_image/train/340.png
#   inflating: Khoa_LHR_image/train/341.png
#   inflating: Khoa_LHR_image/train/342.png
#   inflating: Khoa_LHR_image/train/343.png
#   inflating: Khoa_LHR_image/train/344.png
#   inflating: Khoa_LHR_image/train/345.png
#   inflating: Khoa_LHR_image/train/346.png
#   inflating: Khoa_LHR_image/train/347.png
#   inflating: Khoa_LHR_image/train/348.png
#   inflating: Khoa_LHR_image/train/349.png
#   inflating: Khoa_LHR_image/train/35.png
#   inflating: Khoa_LHR_image/train/350.png
#   inflating: Khoa_LHR_image/train/351.png
#   inflating: Khoa_LHR_image/train/352.png
#   inflating: Khoa_LHR_image/train/353.png
#   inflating: Khoa_LHR_image/train/354.png
#   inflating: Khoa_LHR_image/train/355.png
#   inflating: Khoa_LHR_image/train/356.png
#   inflating: Khoa_LHR_image/train/357.png
#   inflating: Khoa_LHR_image/train/358.png
#   inflating: Khoa_LHR_image/train/359.png
#   inflating: Khoa_LHR_image/train/36.png
#   inflating: Khoa_LHR_image/train/360.png
#   inflating: Khoa_LHR_image/train/361.png
#   inflating: Khoa_LHR_image/train/362.png
#   inflating: Khoa_LHR_image/train/363.png
#   inflating: Khoa_LHR_image/train/364.png
#   inflating: Khoa_LHR_image/train/365.png
#   inflating: Khoa_LHR_image/train/366.png
#   inflating: Khoa_LHR_image/train/367.png
#   inflating: Khoa_LHR_image/train/368.png
#   inflating: Khoa_LHR_image/train/369.png
#   inflating: Khoa_LHR_image/train/37.png
#   inflating: Khoa_LHR_image/train/370.png
#   inflating: Khoa_LHR_image/train/371.png
#   inflating: Khoa_LHR_image/train/372.png
#   inflating: Khoa_LHR_image/train/373.png
#   inflating: Khoa_LHR_image/train/374.png
#   inflating: Khoa_LHR_image/train/375.png
#   inflating: Khoa_LHR_image/train/376.png
#   inflating: Khoa_LHR_image/train/377.png
#   inflating: Khoa_LHR_image/train/378.png
#   inflating: Khoa_LHR_image/train/379.png
#   inflating: Khoa_LHR_image/train/38.png
#   inflating: Khoa_LHR_image/train/380.png
#   inflating: Khoa_LHR_image/train/381.png
#   inflating: Khoa_LHR_image/train/382.png
#   inflating: Khoa_LHR_image/train/383.png
#   inflating: Khoa_LHR_image/train/384.png
#   inflating: Khoa_LHR_image/train/385.png
#   inflating: Khoa_LHR_image/train/386.png
#   inflating: Khoa_LHR_image/train/387.png
#   inflating: Khoa_LHR_image/train/388.png
#   inflating: Khoa_LHR_image/train/389.png
#   inflating: Khoa_LHR_image/train/39.png
#   inflating: Khoa_LHR_image/train/390.png
#   inflating: Khoa_LHR_image/train/391.png
#   inflating: Khoa_LHR_image/train/392.png
#   inflating: Khoa_LHR_image/train/393.png
#   inflating: Khoa_LHR_image/train/394.png
#   inflating: Khoa_LHR_image/train/395.png
#   inflating: Khoa_LHR_image/train/396.png
#   inflating: Khoa_LHR_image/train/397.png
#   inflating: Khoa_LHR_image/train/398.png
#   inflating: Khoa_LHR_image/train/399.png
#   inflating: Khoa_LHR_image/train/4.png
#   inflating: Khoa_LHR_image/train/40.png
#   inflating: Khoa_LHR_image/train/400.png
#   inflating: Khoa_LHR_image/train/401.png
#   inflating: Khoa_LHR_image/train/402.png
#   inflating: Khoa_LHR_image/train/403.png
#   inflating: Khoa_LHR_image/train/404.png
#   inflating: Khoa_LHR_image/train/405.png
#   inflating: Khoa_LHR_image/train/406.png
#   inflating: Khoa_LHR_image/train/407.png
#   inflating: Khoa_LHR_image/train/408.png
#   inflating: Khoa_LHR_image/train/409.png
#   inflating: Khoa_LHR_image/train/41.png
#   inflating: Khoa_LHR_image/train/410.png
#   inflating: Khoa_LHR_image/train/411.png
#   inflating: Khoa_LHR_image/train/412.png
#   inflating: Khoa_LHR_image/train/413.png
#   inflating: Khoa_LHR_image/train/414.png
#   inflating: Khoa_LHR_image/train/415.png
#   inflating: Khoa_LHR_image/train/416.png
#   inflating: Khoa_LHR_image/train/417.png
#   inflating: Khoa_LHR_image/train/418.png
#   inflating: Khoa_LHR_image/train/419.png
#   inflating: Khoa_LHR_image/train/42.png
#   inflating: Khoa_LHR_image/train/420.png
#   inflating: Khoa_LHR_image/train/421.png
#   inflating: Khoa_LHR_image/train/422.png
#   inflating: Khoa_LHR_image/train/423.png
#   inflating: Khoa_LHR_image/train/424.png
#   inflating: Khoa_LHR_image/train/425.png
#   inflating: Khoa_LHR_image/train/426.png
#   inflating: Khoa_LHR_image/train/427.png
#   inflating: Khoa_LHR_image/train/428.png
#   inflating: Khoa_LHR_image/train/429.png
#   inflating: Khoa_LHR_image/train/43.png
#   inflating: Khoa_LHR_image/train/430.png
#   inflating: Khoa_LHR_image/train/431.png
#   inflating: Khoa_LHR_image/train/432.png
#   inflating: Khoa_LHR_image/train/433.png
#   inflating: Khoa_LHR_image/train/434.png
#   inflating: Khoa_LHR_image/train/435.png
#   inflating: Khoa_LHR_image/train/436.png
#   inflating: Khoa_LHR_image/train/437.png
#   inflating: Khoa_LHR_image/train/438.png
#   inflating: Khoa_LHR_image/train/439.png
#   inflating: Khoa_LHR_image/train/44.png
#   inflating: Khoa_LHR_image/train/440.png
#   inflating: Khoa_LHR_image/train/441.png
#   inflating: Khoa_LHR_image/train/442.png
#   inflating: Khoa_LHR_image/train/443.png
#   inflating: Khoa_LHR_image/train/444.png
#   inflating: Khoa_LHR_image/train/445.png
#   inflating: Khoa_LHR_image/train/446.png
#   inflating: Khoa_LHR_image/train/447.png
#   inflating: Khoa_LHR_image/train/448.png
#   inflating: Khoa_LHR_image/train/449.png
#   inflating: Khoa_LHR_image/train/45.png
#   inflating: Khoa_LHR_image/train/450.png
#   inflating: Khoa_LHR_image/train/451.png
#   inflating: Khoa_LHR_image/train/452.png
#   inflating: Khoa_LHR_image/train/453.png
#   inflating: Khoa_LHR_image/train/454.png
#   inflating: Khoa_LHR_image/train/455.png
#   inflating: Khoa_LHR_image/train/456.png
#   inflating: Khoa_LHR_image/train/457.png
#   inflating: Khoa_LHR_image/train/458.png
#   inflating: Khoa_LHR_image/train/459.png
#   inflating: Khoa_LHR_image/train/46.png
#   inflating: Khoa_LHR_image/train/460.png
#   inflating: Khoa_LHR_image/train/461.png
#   inflating: Khoa_LHR_image/train/462.png
#   inflating: Khoa_LHR_image/train/463.png
#   inflating: Khoa_LHR_image/train/464.png
#   inflating: Khoa_LHR_image/train/465.png
#   inflating: Khoa_LHR_image/train/466.png
#   inflating: Khoa_LHR_image/train/467.png
#   inflating: Khoa_LHR_image/train/468.png
#   inflating: Khoa_LHR_image/train/469.png
#   inflating: Khoa_LHR_image/train/47.png
#   inflating: Khoa_LHR_image/train/470.png
#   inflating: Khoa_LHR_image/train/471.png
#   inflating: Khoa_LHR_image/train/472.png
#   inflating: Khoa_LHR_image/train/473.png
#   inflating: Khoa_LHR_image/train/474.png
#   inflating: Khoa_LHR_image/train/475.png
#   inflating: Khoa_LHR_image/train/476.png
#   inflating: Khoa_LHR_image/train/477.png
#   inflating: Khoa_LHR_image/train/478.png
#   inflating: Khoa_LHR_image/train/479.png
#   inflating: Khoa_LHR_image/train/48.png
#   inflating: Khoa_LHR_image/train/480.png
#   inflating: Khoa_LHR_image/train/481.png
#   inflating: Khoa_LHR_image/train/482.png
#   inflating: Khoa_LHR_image/train/483.png
#   inflating: Khoa_LHR_image/train/484.png
#   inflating: Khoa_LHR_image/train/485.png
#   inflating: Khoa_LHR_image/train/486.png
#   inflating: Khoa_LHR_image/train/487.png
#   inflating: Khoa_LHR_image/train/488.png
#   inflating: Khoa_LHR_image/train/489.png
#   inflating: Khoa_LHR_image/train/49.png
#   inflating: Khoa_LHR_image/train/490.png
#   inflating: Khoa_LHR_image/train/491.png
#   inflating: Khoa_LHR_image/train/492.png
#   inflating: Khoa_LHR_image/train/493.png
#   inflating: Khoa_LHR_image/train/494.png
#   inflating: Khoa_LHR_image/train/495.png
#   inflating: Khoa_LHR_image/train/496.png
#   inflating: Khoa_LHR_image/train/497.png
#   inflating: Khoa_LHR_image/train/498.png
#   inflating: Khoa_LHR_image/train/499.png
#   inflating: Khoa_LHR_image/train/5.png
#   inflating: Khoa_LHR_image/train/50.png
#   inflating: Khoa_LHR_image/train/500.png
#   inflating: Khoa_LHR_image/train/501.png
#   inflating: Khoa_LHR_image/train/502.png
#   inflating: Khoa_LHR_image/train/503.png
#   inflating: Khoa_LHR_image/train/504.png
#   inflating: Khoa_LHR_image/train/505.png
#   inflating: Khoa_LHR_image/train/506.png
#   inflating: Khoa_LHR_image/train/507.png
#   inflating: Khoa_LHR_image/train/508.png
#   inflating: Khoa_LHR_image/train/509.png
#   inflating: Khoa_LHR_image/train/51.png
#   inflating: Khoa_LHR_image/train/510.png
#   inflating: Khoa_LHR_image/train/511.png
#   inflating: Khoa_LHR_image/train/512.png
#   inflating: Khoa_LHR_image/train/513.png
#   inflating: Khoa_LHR_image/train/514.png
#   inflating: Khoa_LHR_image/train/515.png
#   inflating: Khoa_LHR_image/train/516.png
#   inflating: Khoa_LHR_image/train/517.png
#   inflating: Khoa_LHR_image/train/518.png
#   inflating: Khoa_LHR_image/train/519.png
#   inflating: Khoa_LHR_image/train/52.png
#   inflating: Khoa_LHR_image/train/520.png
#   inflating: Khoa_LHR_image/train/521.png
#   inflating: Khoa_LHR_image/train/522.png
#   inflating: Khoa_LHR_image/train/523.png
#   inflating: Khoa_LHR_image/train/524.png
#   inflating: Khoa_LHR_image/train/525.png
#   inflating: Khoa_LHR_image/train/526.png
#   inflating: Khoa_LHR_image/train/527.png
#   inflating: Khoa_LHR_image/train/528.png
#   inflating: Khoa_LHR_image/train/529.png
#   inflating: Khoa_LHR_image/train/53.png
#   inflating: Khoa_LHR_image/train/530.png
#   inflating: Khoa_LHR_image/train/531.png
#   inflating: Khoa_LHR_image/train/532.png
#   inflating: Khoa_LHR_image/train/533.png
#   inflating: Khoa_LHR_image/train/534.png
#   inflating: Khoa_LHR_image/train/535.png
#   inflating: Khoa_LHR_image/train/536.png
#   inflating: Khoa_LHR_image/train/537.png
#   inflating: Khoa_LHR_image/train/538.png
#   inflating: Khoa_LHR_image/train/539.png
#   inflating: Khoa_LHR_image/train/54.png
#   inflating: Khoa_LHR_image/train/540.png
#   inflating: Khoa_LHR_image/train/541.png
#   inflating: Khoa_LHR_image/train/542.png
#   inflating: Khoa_LHR_image/train/543.png
#   inflating: Khoa_LHR_image/train/544.png
#   inflating: Khoa_LHR_image/train/545.png
#   inflating: Khoa_LHR_image/train/546.png
#   inflating: Khoa_LHR_image/train/547.png
#   inflating: Khoa_LHR_image/train/548.png
#   inflating: Khoa_LHR_image/train/549.png
#   inflating: Khoa_LHR_image/train/55.png
#   inflating: Khoa_LHR_image/train/550.png
#   inflating: Khoa_LHR_image/train/551.png
#   inflating: Khoa_LHR_image/train/552.png
#   inflating: Khoa_LHR_image/train/553.png
#   inflating: Khoa_LHR_image/train/554.png
#   inflating: Khoa_LHR_image/train/555.png
#   inflating: Khoa_LHR_image/train/556.png
#   inflating: Khoa_LHR_image/train/557.png
#   inflating: Khoa_LHR_image/train/558.png
#   inflating: Khoa_LHR_image/train/559.png
#   inflating: Khoa_LHR_image/train/56.png
#   inflating: Khoa_LHR_image/train/560.png
#   inflating: Khoa_LHR_image/train/561.png
#   inflating: Khoa_LHR_image/train/562.png
#   inflating: Khoa_LHR_image/train/563.png
#   inflating: Khoa_LHR_image/train/564.png
#   inflating: Khoa_LHR_image/train/565.png
#   inflating: Khoa_LHR_image/train/566.png
#   inflating: Khoa_LHR_image/train/567.png
#   inflating: Khoa_LHR_image/train/568.png
#   inflating: Khoa_LHR_image/train/569.png
#   inflating: Khoa_LHR_image/train/57.png
#   inflating: Khoa_LHR_image/train/570.png
#   inflating: Khoa_LHR_image/train/571.png
#   inflating: Khoa_LHR_image/train/572.png
#   inflating: Khoa_LHR_image/train/573.png
#   inflating: Khoa_LHR_image/train/574.png
#   inflating: Khoa_LHR_image/train/575.png
#   inflating: Khoa_LHR_image/train/576.png
#   inflating: Khoa_LHR_image/train/577.png
#   inflating: Khoa_LHR_image/train/578.png
#   inflating: Khoa_LHR_image/train/579.png
#   inflating: Khoa_LHR_image/train/58.png
#   inflating: Khoa_LHR_image/train/580.png
#   inflating: Khoa_LHR_image/train/581.png
#   inflating: Khoa_LHR_image/train/582.png
#   inflating: Khoa_LHR_image/train/583.png
#   inflating: Khoa_LHR_image/train/584.png
#   inflating: Khoa_LHR_image/train/585.png
#   inflating: Khoa_LHR_image/train/586.png
#   inflating: Khoa_LHR_image/train/587.png
#   inflating: Khoa_LHR_image/train/588.png
#   inflating: Khoa_LHR_image/train/589.png
#   inflating: Khoa_LHR_image/train/59.png
#   inflating: Khoa_LHR_image/train/590.png
#   inflating: Khoa_LHR_image/train/591.png
#   inflating: Khoa_LHR_image/train/592.png
#   inflating: Khoa_LHR_image/train/593.png
#   inflating: Khoa_LHR_image/train/594.png
#   inflating: Khoa_LHR_image/train/595.png
#   inflating: Khoa_LHR_image/train/596.png
#   inflating: Khoa_LHR_image/train/597.png
#   inflating: Khoa_LHR_image/train/598.png
#   inflating: Khoa_LHR_image/train/599.png
#   inflating: Khoa_LHR_image/train/6.png
#   inflating: Khoa_LHR_image/train/60.png
#   inflating: Khoa_LHR_image/train/600.png
#   inflating: Khoa_LHR_image/train/601.png
#   inflating: Khoa_LHR_image/train/602.png
#   inflating: Khoa_LHR_image/train/603.png
#   inflating: Khoa_LHR_image/train/604.png
#   inflating: Khoa_LHR_image/train/605.png
#   inflating: Khoa_LHR_image/train/606.png
#   inflating: Khoa_LHR_image/train/607.png
#   inflating: Khoa_LHR_image/train/608.png
#   inflating: Khoa_LHR_image/train/609.png
#   inflating: Khoa_LHR_image/train/61.png
#   inflating: Khoa_LHR_image/train/610.png
#   inflating: Khoa_LHR_image/train/611.png
#   inflating: Khoa_LHR_image/train/612.png
#   inflating: Khoa_LHR_image/train/613.png
#   inflating: Khoa_LHR_image/train/614.png
#   inflating: Khoa_LHR_image/train/615.png
#   inflating: Khoa_LHR_image/train/616.png
#   inflating: Khoa_LHR_image/train/617.png
#   inflating: Khoa_LHR_image/train/618.png
#   inflating: Khoa_LHR_image/train/619.png
#   inflating: Khoa_LHR_image/train/62.png
#   inflating: Khoa_LHR_image/train/620.png
#   inflating: Khoa_LHR_image/train/621.png
#   inflating: Khoa_LHR_image/train/622.png
#   inflating: Khoa_LHR_image/train/623.png
#   inflating: Khoa_LHR_image/train/624.png
#   inflating: Khoa_LHR_image/train/625.png
#   inflating: Khoa_LHR_image/train/626.png
#   inflating: Khoa_LHR_image/train/627.png
#   inflating: Khoa_LHR_image/train/628.png
#   inflating: Khoa_LHR_image/train/629.png
#   inflating: Khoa_LHR_image/train/63.png
#   inflating: Khoa_LHR_image/train/630.png
#   inflating: Khoa_LHR_image/train/631.png
#   inflating: Khoa_LHR_image/train/632.png
#   inflating: Khoa_LHR_image/train/633.png
#   inflating: Khoa_LHR_image/train/634.png
#   inflating: Khoa_LHR_image/train/635.png
#   inflating: Khoa_LHR_image/train/636.png
#   inflating: Khoa_LHR_image/train/637.png
#   inflating: Khoa_LHR_image/train/638.png
#   inflating: Khoa_LHR_image/train/639.png
#   inflating: Khoa_LHR_image/train/64.png
#   inflating: Khoa_LHR_image/train/640.png
#   inflating: Khoa_LHR_image/train/641.png
#   inflating: Khoa_LHR_image/train/642.png
#   inflating: Khoa_LHR_image/train/643.png
#   inflating: Khoa_LHR_image/train/644.png
#   inflating: Khoa_LHR_image/train/645.png
#   inflating: Khoa_LHR_image/train/646.png
#   inflating: Khoa_LHR_image/train/647.png
#   inflating: Khoa_LHR_image/train/648.png
#   inflating: Khoa_LHR_image/train/649.png
#   inflating: Khoa_LHR_image/train/65.png
#   inflating: Khoa_LHR_image/train/650.png
#   inflating: Khoa_LHR_image/train/651.png
#   inflating: Khoa_LHR_image/train/652.png
#   inflating: Khoa_LHR_image/train/653.png
#   inflating: Khoa_LHR_image/train/654.png
#   inflating: Khoa_LHR_image/train/655.png
#   inflating: Khoa_LHR_image/train/656.png
#   inflating: Khoa_LHR_image/train/657.png
#   inflating: Khoa_LHR_image/train/658.png
#   inflating: Khoa_LHR_image/train/659.png
#   inflating: Khoa_LHR_image/train/66.png
#   inflating: Khoa_LHR_image/train/660.png
#   inflating: Khoa_LHR_image/train/661.png
#   inflating: Khoa_LHR_image/train/662.png
#   inflating: Khoa_LHR_image/train/663.png
#   inflating: Khoa_LHR_image/train/664.png
#   inflating: Khoa_LHR_image/train/665.png
#   inflating: Khoa_LHR_image/train/666.png
#   inflating: Khoa_LHR_image/train/667.png
#   inflating: Khoa_LHR_image/train/668.png
#   inflating: Khoa_LHR_image/train/669.png
#   inflating: Khoa_LHR_image/train/67.png
#   inflating: Khoa_LHR_image/train/670.png
#   inflating: Khoa_LHR_image/train/671.png
#   inflating: Khoa_LHR_image/train/672.png
#   inflating: Khoa_LHR_image/train/673.png
#   inflating: Khoa_LHR_image/train/674.png
#   inflating: Khoa_LHR_image/train/675.png
#   inflating: Khoa_LHR_image/train/676.png
#   inflating: Khoa_LHR_image/train/677.png
#   inflating: Khoa_LHR_image/train/678.png
#   inflating: Khoa_LHR_image/train/679.png
#   inflating: Khoa_LHR_image/train/68.png
#   inflating: Khoa_LHR_image/train/680.png
#   inflating: Khoa_LHR_image/train/681.png
#   inflating: Khoa_LHR_image/train/682.png
#   inflating: Khoa_LHR_image/train/683.png
#   inflating: Khoa_LHR_image/train/684.png
#   inflating: Khoa_LHR_image/train/69.png
#   inflating: Khoa_LHR_image/train/7.png
#   inflating: Khoa_LHR_image/train/70.png
#   inflating: Khoa_LHR_image/train/71.png
#   inflating: Khoa_LHR_image/train/72.png
#   inflating: Khoa_LHR_image/train/73.png
#   inflating: Khoa_LHR_image/train/74.png
#   inflating: Khoa_LHR_image/train/75.png
#   inflating: Khoa_LHR_image/train/76.png
#   inflating: Khoa_LHR_image/train/77.png
#   inflating: Khoa_LHR_image/train/78.png
#   inflating: Khoa_LHR_image/train/79.png
#   inflating: Khoa_LHR_image/train/8.png
#   inflating: Khoa_LHR_image/train/80.png
#   inflating: Khoa_LHR_image/train/81.png
#   inflating: Khoa_LHR_image/train/82.png
#   inflating: Khoa_LHR_image/train/83.png
#   inflating: Khoa_LHR_image/train/84.png
#   inflating: Khoa_LHR_image/train/85.png
#   inflating: Khoa_LHR_image/train/86.png
#   inflating: Khoa_LHR_image/train/87.png
#   inflating: Khoa_LHR_image/train/88.png
#   inflating: Khoa_LHR_image/train/89.png
#   inflating: Khoa_LHR_image/train/9.png
#   inflating: Khoa_LHR_image/train/90.png
#   inflating: Khoa_LHR_image/train/91.png
#   inflating: Khoa_LHR_image/train/92.png
#   inflating: Khoa_LHR_image/train/93.png
#   inflating: Khoa_LHR_image/train/94.png
#   inflating: Khoa_LHR_image/train/95.png
#   inflating: Khoa_LHR_image/train/96.png
#   inflating: Khoa_LHR_image/train/97.png
#   inflating: Khoa_LHR_image/train/98.png
#   inflating: Khoa_LHR_image/train/99.png
#    creating: Khoa_LHR_image/val/
#   inflating: Khoa_LHR_image/val/0.png
#   inflating: Khoa_LHR_image/val/1.png
#   inflating: Khoa_LHR_image/val/10.png
#   inflating: Khoa_LHR_image/val/100.png
#   inflating: Khoa_LHR_image/val/101.png
#   inflating: Khoa_LHR_image/val/102.png
#   inflating: Khoa_LHR_image/val/103.png
#   inflating: Khoa_LHR_image/val/104.png
#   inflating: Khoa_LHR_image/val/105.png
#   inflating: Khoa_LHR_image/val/106.png
#   inflating: Khoa_LHR_image/val/107.png
#   inflating: Khoa_LHR_image/val/108.png
#   inflating: Khoa_LHR_image/val/109.png
#   inflating: Khoa_LHR_image/val/11.png
#   inflating: Khoa_LHR_image/val/110.png
#   inflating: Khoa_LHR_image/val/111.png
#   inflating: Khoa_LHR_image/val/112.png
#   inflating: Khoa_LHR_image/val/113.png
#   inflating: Khoa_LHR_image/val/114.png
#   inflating: Khoa_LHR_image/val/115.png
#   inflating: Khoa_LHR_image/val/116.png
#   inflating: Khoa_LHR_image/val/117.png
#   inflating: Khoa_LHR_image/val/118.png
#   inflating: Khoa_LHR_image/val/119.png
#   inflating: Khoa_LHR_image/val/12.png
#   inflating: Khoa_LHR_image/val/120.png
#   inflating: Khoa_LHR_image/val/121.png
#   inflating: Khoa_LHR_image/val/122.png
#   inflating: Khoa_LHR_image/val/123.png
#   inflating: Khoa_LHR_image/val/124.png
#   inflating: Khoa_LHR_image/val/125.png
#   inflating: Khoa_LHR_image/val/126.png
#   inflating: Khoa_LHR_image/val/127.png
#   inflating: Khoa_LHR_image/val/128.png
#   inflating: Khoa_LHR_image/val/129.png
#   inflating: Khoa_LHR_image/val/13.png
#   inflating: Khoa_LHR_image/val/130.png
#   inflating: Khoa_LHR_image/val/131.png
#   inflating: Khoa_LHR_image/val/132.png
#   inflating: Khoa_LHR_image/val/133.png
#   inflating: Khoa_LHR_image/val/134.png
#   inflating: Khoa_LHR_image/val/135.png
#   inflating: Khoa_LHR_image/val/136.png
#   inflating: Khoa_LHR_image/val/137.png
#   inflating: Khoa_LHR_image/val/138.png
#   inflating: Khoa_LHR_image/val/139.png
#   inflating: Khoa_LHR_image/val/14.png
#   inflating: Khoa_LHR_image/val/140.png
#   inflating: Khoa_LHR_image/val/141.png
#   inflating: Khoa_LHR_image/val/142.png
#   inflating: Khoa_LHR_image/val/143.png
#   inflating: Khoa_LHR_image/val/144.png
#   inflating: Khoa_LHR_image/val/145.png
#   inflating: Khoa_LHR_image/val/146.png
#   inflating: Khoa_LHR_image/val/147.png
#   inflating: Khoa_LHR_image/val/148.png
#   inflating: Khoa_LHR_image/val/149.png
#   inflating: Khoa_LHR_image/val/15.png
#   inflating: Khoa_LHR_image/val/150.png
#   inflating: Khoa_LHR_image/val/151.png
#   inflating: Khoa_LHR_image/val/152.png
#   inflating: Khoa_LHR_image/val/153.png
#   inflating: Khoa_LHR_image/val/154.png
#   inflating: Khoa_LHR_image/val/155.png
#   inflating: Khoa_LHR_image/val/156.png
#   inflating: Khoa_LHR_image/val/157.png
#   inflating: Khoa_LHR_image/val/158.png
#   inflating: Khoa_LHR_image/val/159.png
#   inflating: Khoa_LHR_image/val/16.png
#   inflating: Khoa_LHR_image/val/160.png
#   inflating: Khoa_LHR_image/val/161.png
#   inflating: Khoa_LHR_image/val/162.png
#   inflating: Khoa_LHR_image/val/163.png
#   inflating: Khoa_LHR_image/val/164.png
#   inflating: Khoa_LHR_image/val/165.png
#   inflating: Khoa_LHR_image/val/166.png
#   inflating: Khoa_LHR_image/val/167.png
#   inflating: Khoa_LHR_image/val/168.png
#   inflating: Khoa_LHR_image/val/169.png
#   inflating: Khoa_LHR_image/val/17.png
#   inflating: Khoa_LHR_image/val/18.png
#   inflating: Khoa_LHR_image/val/19.png
#   inflating: Khoa_LHR_image/val/2.png
#   inflating: Khoa_LHR_image/val/20.png
#   inflating: Khoa_LHR_image/val/21.png
#   inflating: Khoa_LHR_image/val/22.png
#   inflating: Khoa_LHR_image/val/23.png
#   inflating: Khoa_LHR_image/val/24.png
#   inflating: Khoa_LHR_image/val/25.png
#   inflating: Khoa_LHR_image/val/26.png
#   inflating: Khoa_LHR_image/val/27.png
#   inflating: Khoa_LHR_image/val/28.png
#   inflating: Khoa_LHR_image/val/29.png
#   inflating: Khoa_LHR_image/val/3.png
#   inflating: Khoa_LHR_image/val/30.png
#   inflating: Khoa_LHR_image/val/31.png
#   inflating: Khoa_LHR_image/val/32.png
#   inflating: Khoa_LHR_image/val/33.png
#   inflating: Khoa_LHR_image/val/34.png
#   inflating: Khoa_LHR_image/val/35.png
#   inflating: Khoa_LHR_image/val/36.png
#   inflating: Khoa_LHR_image/val/37.png
#   inflating: Khoa_LHR_image/val/38.png
#   inflating: Khoa_LHR_image/val/39.png
#   inflating: Khoa_LHR_image/val/4.png
#   inflating: Khoa_LHR_image/val/40.png
#   inflating: Khoa_LHR_image/val/41.png
#   inflating: Khoa_LHR_image/val/42.png
#   inflating: Khoa_LHR_image/val/43.png
#   inflating: Khoa_LHR_image/val/44.png
#   inflating: Khoa_LHR_image/val/45.png
#   inflating: Khoa_LHR_image/val/46.png
#   inflating: Khoa_LHR_image/val/47.png
#   inflating: Khoa_LHR_image/val/48.png
#   inflating: Khoa_LHR_image/val/49.png
#   inflating: Khoa_LHR_image/val/5.png
#   inflating: Khoa_LHR_image/val/50.png
#   inflating: Khoa_LHR_image/val/51.png
#   inflating: Khoa_LHR_image/val/52.png
#   inflating: Khoa_LHR_image/val/53.png
#   inflating: Khoa_LHR_image/val/54.png
#   inflating: Khoa_LHR_image/val/55.png
#   inflating: Khoa_LHR_image/val/56.png
#   inflating: Khoa_LHR_image/val/57.png
#   inflating: Khoa_LHR_image/val/58.png
#   inflating: Khoa_LHR_image/val/59.png
#   inflating: Khoa_LHR_image/val/6.png
#   inflating: Khoa_LHR_image/val/60.png
#   inflating: Khoa_LHR_image/val/61.png
#   inflating: Khoa_LHR_image/val/62.png
#   inflating: Khoa_LHR_image/val/63.png
#   inflating: Khoa_LHR_image/val/64.png
#   inflating: Khoa_LHR_image/val/65.png
#   inflating: Khoa_LHR_image/val/66.png
#   inflating: Khoa_LHR_image/val/67.png
#   inflating: Khoa_LHR_image/val/68.png
#   inflating: Khoa_LHR_image/val/69.png
#   inflating: Khoa_LHR_image/val/7.png
#   inflating: Khoa_LHR_image/val/70.png
#   inflating: Khoa_LHR_image/val/71.png
#   inflating: Khoa_LHR_image/val/72.png
#   inflating: Khoa_LHR_image/val/73.png
#   inflating: Khoa_LHR_image/val/74.png
#   inflating: Khoa_LHR_image/val/75.png
#   inflating: Khoa_LHR_image/val/76.png
#   inflating: Khoa_LHR_image/val/77.png
#   inflating: Khoa_LHR_image/val/78.png
#   inflating: Khoa_LHR_image/val/79.png
#   inflating: Khoa_LHR_image/val/8.png
#   inflating: Khoa_LHR_image/val/80.png
#   inflating: Khoa_LHR_image/val/81.png
#   inflating: Khoa_LHR_image/val/82.png
#   inflating: Khoa_LHR_image/val/83.png
#   inflating: Khoa_LHR_image/val/84.png
#   inflating: Khoa_LHR_image/val/85.png
#   inflating: Khoa_LHR_image/val/86.png
#   inflating: Khoa_LHR_image/val/87.png
#   inflating: Khoa_LHR_image/val/88.png
#   inflating: Khoa_LHR_image/val/89.png
#   inflating: Khoa_LHR_image/val/9.png
#   inflating: Khoa_LHR_image/val/90.png
#   inflating: Khoa_LHR_image/val/91.png
#   inflating: Khoa_LHR_image/val/92.png
#   inflating: Khoa_LHR_image/val/93.png
#   inflating: Khoa_LHR_image/val/94.png
#   inflating: Khoa_LHR_image/val/95.png
#   inflating: Khoa_LHR_image/val/96.png
#   inflating: Khoa_LHR_image/val/97.png
#   inflating: Khoa_LHR_image/val/98.png
#   inflating: Khoa_LHR_image/val/99.png

# %%
import torch
from torch import nn
from torch.utils.data import Dataset, DataLoader
from torch import optim
from PIL import Image
from torchvision import transforms
import os
import matplotlib.pyplot as plt
import numpy as np
from torcheval.metrics.functional import peak_signal_noise_ratio
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
torch.manual_seed(66)

# %% [markdown]
# ## Problem 2: Super Resolution with UNET

# %%
LHR_TRAIN_DATA_PATH = '/content/Khoa_LHR_image/train'
LHR_VAL_DATA_PATH = '/content/Khoa_LHR_image/val'
BATCH_SIZE = 8
LOW_IMG_HEIGHT = 64
LOW_IMG_WIDTH = 64

# %% [markdown]
# ### Unet for Super Resolution Task

# %% [markdown]
# #### No skip connection

# %%
class FirstFeatureNoSkip(nn.Module):
    def __init__(self, in_channels, out_channels):
        super(FirstFeatureNoSkip, self).__init__()
        self.conv = nn.Sequential(
            nn.Conv2d(in_channels, out_channels, 1, 1, 0, bias=False),
            nn.LeakyReLU()
        )

    def forward(self, x):
        return self.conv(x)


class ConvBlockNoSkip(nn.Module):
    def __init__(self, in_channels, out_channels):
        super(ConvBlockNoSkip, self).__init__()
        self.conv = nn.Sequential(
            nn.Conv2d(in_channels, out_channels, 3, 1, 1, bias=False),
            nn.BatchNorm2d(out_channels),
            nn.LeakyReLU(inplace=True),
            nn.Conv2d(out_channels, out_channels, 3, 1, 1, bias=False),
            nn.BatchNorm2d(out_channels),
            nn.LeakyReLU(inplace=True),
        )

    def forward(self, x):
        return self.conv(x)


class EncoderNoSkip(nn.Module):
    def __init__(self, in_channels, out_channels) -> None:
        super(EncoderNoSkip, self).__init__()
        self.encoder = nn.Sequential(
            nn.MaxPool2d(2),
            ConvBlockNoSkip(in_channels, out_channels)
        )

    def forward(self, x):
        x = self.encoder(x)
        return x


class DecoderNoSkip(nn.Module):
    def __init__(self, in_channels, out_channels):
        super(DecoderNoSkip, self).__init__()
        self.conv = nn.Sequential(
            nn.UpsamplingBilinear2d(scale_factor=2),
            nn.Conv2d(in_channels, out_channels*2, 1, 1, 0, bias=False),
            nn.BatchNorm2d(out_channels*2),
            nn.LeakyReLU(),
        )
        self.conv_block = ConvBlockNoSkip(out_channels*2, out_channels)

    def forward(self, x):
        x = self.conv(x)
        x = self.conv_block(x)
        return x


class FinalOutputNoSkip(nn.Module):
    def __init__(self, in_channels, out_channels):
        super(FinalOutputNoSkip, self).__init__()
        self.conv = nn.Sequential(
            nn.Conv2d(in_channels, out_channels, 1, 1, 0, bias=False),
            nn.Tanh()
        )

    def forward(self, x):
        return self.conv(x)


class SR_Unet_NoSkip(nn.Module):
    def __init__(
            self, n_channels=3, n_classes=3
    ):
        super(SR_Unet_NoSkip, self).__init__()

        self.n_channels = n_channels
        self.n_classes = n_classes
        self.resize_fnc = transforms.Resize((LOW_IMG_HEIGHT*4, LOW_IMG_HEIGHT*4),
                                             antialias=True)
        self.in_conv1 = FirstFeatureNoSkip(n_channels, 64)
        self.in_conv2 = ConvBlockNoSkip(64, 64)

        self.enc_1 = EncoderNoSkip(64, 128)
        self.enc_2 = EncoderNoSkip(128, 256)
        self.enc_3 = EncoderNoSkip(256, 512)
        self.enc_4 = EncoderNoSkip(512, 1024)

        self.dec_1 = DecoderNoSkip(1024, 512)
        self.dec_2 = DecoderNoSkip(512, 256)
        self.dec_3 = DecoderNoSkip(256, 128)
        self.dec_4 = DecoderNoSkip(128, 64)

        self.out_conv = FinalOutputNoSkip(64, n_classes)


    def forward(self, x):
        x = self.resize_fnc(x)
        x = self.in_conv1(x)
        x = self.in_conv2(x)

        x = self.enc_1(x)
        x = self.enc_2(x)
        x = self.enc_3(x)
        x = self.enc_4(x)

        x = self.dec_1(x)
        x = self.dec_2(x)
        x = self.dec_3(x)
        x = self.dec_4(x)

        x = self.out_conv(x)
        return x

# %%
unet_model = SR_Unet_NoSkip().to(device)
img = torch.ones(2, 3, 64, 64).to(device)
unet_model(img).shape
# Out:
# torch.Size([2, 3, 256, 256])

# %% [markdown]
# #### Skip connection

# %%
class FirstFeature(nn.Module):
    def __init__(self, in_channels, out_channels):
        super(FirstFeature, self).__init__()
        self.conv = nn.Sequential(
            nn.Conv2d(in_channels, out_channels, 1, 1, 0, bias=False),
            nn.LeakyReLU()
        )

    def forward(self, x):
        return self.conv(x)


class ConvBlock(nn.Module):
    def __init__(self, in_channels, out_channels):
        super(ConvBlock, self).__init__()
        self.conv = nn.Sequential(
            nn.Conv2d(in_channels, out_channels, 3, 1, 1, bias=False),
            nn.BatchNorm2d(out_channels),
            nn.LeakyReLU(inplace=True),
            nn.Conv2d(out_channels, out_channels, 3, 1, 1, bias=False),
            nn.BatchNorm2d(out_channels),
            nn.LeakyReLU(inplace=True),
        )

    def forward(self, x):
        return self.conv(x)


class Encoder(nn.Module):
    def __init__(self, in_channels, out_channels) -> None:
        super().__init__()
        self.encoder = nn.Sequential(
            nn.MaxPool2d(2),
            ConvBlock(in_channels, out_channels)
        )

    def forward(self, x):
        x = self.encoder(x)
        return x


class Decoder(nn.Module):
    def __init__(self, in_channels, out_channels):
        super(Decoder, self).__init__()
        self.conv = nn.Sequential(
            nn.UpsamplingBilinear2d(scale_factor=2),
            nn.Conv2d(in_channels, out_channels, 1, 1, 0, bias=False),
            nn.BatchNorm2d(out_channels),
            nn.LeakyReLU(),
        )
        self.conv_block = ConvBlock(in_channels, out_channels)

    def forward(self, x, skip):
        x = self.conv(x)
        x = torch.concat([x, skip], dim=1)
        x = self.conv_block(x)
        return x


class FinalOutput(nn.Module):
    def __init__(self, in_channels, out_channels):
        super(FinalOutput, self).__init__()
        self.conv = nn.Sequential(
            nn.Conv2d(in_channels, out_channels, 1, 1, 0, bias=False),
            nn.Tanh()
        )

    def forward(self, x):
        return self.conv(x)


class SR_Unet(nn.Module):
    def __init__(
            self, n_channels=3, n_classes=3
    ):
        super(SR_Unet, self).__init__()

        self.n_channels = n_channels
        self.n_classes = n_classes
        self.resize_fnc = transforms.Resize((LOW_IMG_HEIGHT*4, LOW_IMG_HEIGHT*4),
                                             antialias=True)
        self.in_conv1 = FirstFeature(n_channels, 64)
        self.in_conv2 = ConvBlock(64, 64)

        self.enc_1 = Encoder(64, 128)
        self.enc_2 = Encoder(128, 256)
        self.enc_3 = Encoder(256, 512)
        self.enc_4 = Encoder(512, 1024)

        self.dec_1 = Decoder(1024, 512)
        self.dec_2 = Decoder(512, 256)
        self.dec_3 = Decoder(256, 128)
        self.dec_4 = Decoder(128, 64)

        self.out_conv = FinalOutput(64, n_classes)


    def forward(self, x):
        x = self.resize_fnc(x)
        x = self.in_conv1(x)
        x1 = self.in_conv2(x)

        x2 = self.enc_1(x1)
        x3 = self.enc_2(x2)
        x4 = self.enc_3(x3)
        x5 = self.enc_4(x4)

        x = self.dec_1(x5, x4)
        x = self.dec_2(x, x3)
        x = self.dec_3(x, x2)
        x = self.dec_4(x, x1)

        x = self.out_conv(x)
        return x

# %%
unet_model = SR_Unet().to(device)
img = torch.ones(2, 3, 64, 64).to(device)
unet_model(img).shape
# Out:
# torch.Size([2, 3, 256, 256])

# %% [markdown]
# ### Prepare Super Resolution Dataset

# %% [markdown]
# #### Split Tran Validation data

# %%
class ImageDataset(Dataset):
    ############################## Your Code Here###########################
    """
    Các bạn dựa vào idea hướng dẫn trong file mô tả bài hãy xây dựng một hàm load data
    cho bài toán Super Resolution (input_image=64x64 và target_image=256x256 ảnh màu).
    Các bạn có thể tự do xây dựng theo từng cá nhân, có thể add thêm hoặc xoá các method không
    cần thiết. Hoặc các bạn có thể tham khảo code hướng dẫn trong file mô tả bài tập
    """
    def __init__(self, img_dir, is_train=True):
        self.resize = transforms.Resize((LOW_IMG_WIDTH, LOW_IMG_HEIGHT), antialias=True)
        self.is_train = is_train
        self.img_dir = img_dir
        self.images = os.listdir(img_dir)

    def __len__(self):
        return len(self.images)

    def normalize(self, input_image, target_image):
        input_image = input_image *2 - 1
        target_image = target_image *2 - 1
        return input_image, target_image

    def random_jitter(self, input_image, target_image):
        if torch.rand([]) < 0.5:
            input_image = transforms.functional.hflip(input_image)
            target_image = transforms.functional.hflip(target_image)
        return input_image, target_image

    def __getitem__(self, idx):
        img_path = os.path.join(self.img_dir, self.images[idx])
        image = np.array(Image.open(img_path).convert('RGB'))
        image = transforms.functional.to_tensor(image)
        input_image = self.resize(image).type(torch.float32)
        target_image = image.type(torch.float32)

        input_image, target_image = self.normalize(input_image, target_image)

        if self.is_train:
            input_image, target_image = self.random_jitter(input_image, target_image)

        return input_image, target_image

    #########################################################################

# %%
train_dataset = ImageDataset(LHR_TRAIN_DATA_PATH, is_train=True)
train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)

test_dataset = ImageDataset(LHR_VAL_DATA_PATH, is_train=False)
test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False)

# %%
in_batch, tar_batch = next(iter(train_loader))
in_batch = (in_batch + 1)/2
tar_batch = (tar_batch + 1)/2

plt.figure(figsize=(10, 10))
ax = plt.subplot(2, 2, 1)
plt.imshow(np.squeeze(in_batch[0].numpy().transpose((1, 2, 0))))
plt.title("Input")
ax = plt.subplot(2, 2, 3)
plt.imshow(np.squeeze(tar_batch[0].numpy().transpose((1, 2, 0))))
plt.title("Target")
ax = plt.subplot(2, 2, 2)
plt.imshow(np.squeeze(in_batch[1].numpy().transpose((1, 2, 0))))
plt.title("Input")
ax = plt.subplot(2, 2, 4)
plt.imshow(np.squeeze(tar_batch[1].numpy().transpose((1, 2, 0))))
plt.title("Target")
# Out:
# Text(0.5, 1.0, 'Target')

# %% [markdown]
# ### Train

# %%
def generate_images(model, inputs, labels):
    model.eval()
    with torch.no_grad():
        inputs, labels = inputs.to(device), labels.to(device)
        predictions = model(inputs)
    inputs, labels, predictions = inputs.cpu().numpy(), labels.cpu().numpy(), predictions.cpu().numpy()
    plt.figure(figsize=(15,20))

    display_list = [inputs[-1].transpose((1, 2, 0)), labels[-1].transpose((1, 2, 0)), predictions[-1].transpose((1, 2, 0))]
    title = ['Input', 'Real', 'Predicted']

    for i in range(3):
        plt.subplot(1, 3, i+1)
        plt.title(title[i])
        plt.imshow((display_list[i] + 1) / 2)
        plt.axis('off')
    plt.show()

# %%
import time

def train_epoch(model, optimizer, criterion, train_dataloader, device, epoch=0,
                log_interval=50):
    model.train()
    total_psnr, total_count = 0, 0
    losses = []
    start_time = time.time()

    for idx, (inputs, labels) in enumerate(train_dataloader):
        inputs = inputs.to(device)
        labels = labels.to(device)

        optimizer.zero_grad()

        predictions = model(inputs)

        # compute loss
        loss = criterion(predictions, labels)
        losses.append(loss.item())

        # backward
        loss.backward()
        optimizer.step()

        total_psnr += peak_signal_noise_ratio(predictions, labels)
        total_count += 1
        if idx % log_interval == 0 and idx > 0:
            elapsed = time.time() - start_time
            print(
                "| epoch {:3d} | {:5d}/{:5d} batches "
                "| psnr {:8.3f}".format(
                    epoch, idx, len(train_dataloader), total_psnr / total_count
                )
            )
            total_psnr, total_count = 0, 0
            start_time = time.time()

    epoch_psnr = total_psnr / total_count
    epoch_loss = sum(losses) / len(losses)
    return epoch_psnr, epoch_loss

# %%
def evaluate_epoch(model, criterion, valid_dataloader, device):
    model.eval()
    total_psnr, total_count = 0, 0
    losses = []

    with torch.no_grad():
        for idx, (inputs, labels) in enumerate(valid_dataloader):
            inputs = inputs.to(device)
            labels = labels.to(device)

            predictions = model(inputs)

            loss = criterion(predictions, labels)
            losses.append(loss.item())


            total_psnr +=  peak_signal_noise_ratio(predictions, labels)
            total_count += 1

    epoch_psnr = total_psnr / total_count
    epoch_loss = sum(losses) / len(losses)
    return epoch_psnr, epoch_loss

# %%
def train(model, model_name, save_model, optimizer, criterion, train_dataloader, valid_dataloader, num_epochs, device):
    train_psnrs, train_losses = [], []
    eval_psnrs, eval_losses = [], []
    best_psnr_eval = -1000
    times = []
    for epoch in range(1, num_epochs+1):
        epoch_start_time = time.time()
        # Training
        train_psnr, train_loss = train_epoch(model, optimizer, criterion, train_dataloader, device, epoch)
        train_psnrs.append(train_psnr.cpu())
        train_losses.append(train_loss)

        # Evaluation
        eval_psnr, eval_loss = evaluate_epoch(model, criterion, valid_dataloader, device)
        eval_psnrs.append(eval_psnr.cpu())
        eval_losses.append(eval_loss)

        # Save best model
        if best_psnr_eval < eval_psnr :
            torch.save(model.state_dict(), save_model + f'/{model_name}.pt')
            inputs_t, targets_t = next(iter(valid_dataloader))
            generate_images(model, inputs_t, targets_t)
            best_psnr_eval = eval_psnr
        times.append(time.time() - epoch_start_time)
        # Print loss, psnr end epoch
        print("-" * 59)
        print(
            "| End of epoch {:3d} | Time: {:5.2f}s | Train psnr {:8.3f} | Train Loss {:8.3f} "
            "| Valid psnr {:8.3f} | Valid Loss {:8.3f} ".format(
                epoch, time.time() - epoch_start_time, train_psnr, train_loss, eval_psnr, eval_loss
            )
        )
        print("-" * 59)

    # Load best model
    model.load_state_dict(torch.load(save_model + f'/{model_name}.pt'))
    model.eval()
    metrics = {
        'train_psnr': train_psnrs,
        'train_loss': train_losses,
        'valid_psnr': eval_psnrs,
        'valid_loss': eval_losses,
        'time': times
    }
    return model, metrics

# %%
import matplotlib.pyplot as plt

def plot_result(num_epochs, train_psnrs, eval_psnrs, train_losses, eval_losses):
    epochs = list(range(num_epochs))
    fig, axs = plt.subplots(nrows = 1, ncols =2 , figsize = (12,6))
    axs[0].plot(epochs, train_psnrs, label = "Training")
    axs[0].plot(epochs, eval_psnrs, label = "Evaluation")
    axs[1].plot(epochs, train_losses, label = "Training")
    axs[1].plot(epochs, eval_losses, label = "Evaluation")
    axs[0].set_xlabel("Epochs")
    axs[1].set_xlabel("Epochs")
    axs[0].set_ylabel("PSNR")
    axs[1].set_ylabel("Loss")
    plt.legend()

# %%
import matplotlib.pyplot as plt

def predict_and_display(model, test_dataloader, device):
    model.eval()

    with torch.no_grad():
        for idx, (inputs, labels) in enumerate(test_dataloader):
            if idx >= 10:
                break
            inputs = inputs.to(device)
            predictions = model(inputs)
            generate_images(model, inputs, labels)
            plt.show()

# %% [markdown]
# #### Unet No Skip Connection

# %%
import torch.optim as optim

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
SR_unet_model_noskip = SR_Unet_NoSkip().to(device)
SR_unet_model_noskip.to(device)

criterion = nn.L1Loss()

optimizer = optim.Adam(SR_unet_model_noskip.parameters(), lr=1e-4, betas=[0.5,0.999])

save_model = './UNET'
os.makedirs(save_model, exist_ok = True)

EPOCHS = 20
SR_unet_model_noskip, metrics = train(
    SR_unet_model_noskip, 'SR_unet_model_noskip', save_model, optimizer, criterion, train_loader, test_loader, EPOCHS, device
)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
plot_result(
    EPOCHS,
    metrics["train_psnr"],
    metrics["valid_psnr"],
    metrics["train_loss"],
    metrics["valid_loss"]
)

# %%
test_psnr, test_loss = evaluate_epoch(SR_unet_model_noskip, criterion, test_loader, device)
test_psnr, test_loss

# %%
predict_and_display(SR_unet_model_noskip, train_loader, device)

# %%
predict_and_display(SR_unet_model_noskip, test_loader, device)

# %% [markdown]
# #### Unet

# %%
import torch.optim as optim

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
SR_unet_model = SR_Unet().to(device)
SR_unet_model.to(device)

criterion = nn.L1Loss()

optimizer = optim.Adam(SR_unet_model.parameters(), lr=1e-4, betas=[0.5,0.999])

save_model = './UNET'
os.makedirs(save_model, exist_ok = True)

EPOCHS = 100
SR_unet_model, metrics = train(
    SR_unet_model, 'SR_unet_model', save_model, optimizer, criterion, train_loader, test_loader, EPOCHS, device
)

# %%
plot_result(
    EPOCHS,
    metrics["train_psnr"],
    metrics["valid_psnr"],
    metrics["train_loss"],
    metrics["valid_loss"]
)

# %%
test_psnr, test_loss = evaluate_epoch(SR_unet_model, criterion, test_loader, device)
test_psnr, test_loss

# %%
predict_and_display(SR_unet_model, train_loader, device)

# %%
predict_and_display(SR_unet_model, test_loader, device)
